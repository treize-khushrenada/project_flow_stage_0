# %% [markdown]
# ### Lyrics Analysis

# %%
# import required packages

# data manipulation
import re
import numpy as np
import pandas as pd
# ignore chain assignment warning 
pd.options.mode.chained_assignment = None

# lyrics retrieval
genius_token = 'JhNas_g4xHymyA1mzCmZ_alk-MpiOVrfihxvlQ4NYjOe2e_XpBRZB7dCgHG3PSij'
import lyricsgenius

# nltk- text tokenization
import nltk
from nltk.tokenize import sent_tokenize

# nltk- vader
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import spacy

# nrc- emotion lexicon scores
from nrclex import NRCLex

# bert- transformer pipelines
from transformers import pipeline

# spotify
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# database
from sqlalchemy import create_engine
import psycopg2 
import io
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/macarthur/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# create new object from lyricsgenius
genius = lyricsgenius.Genius(genius_token)

# %%
# testing nrc lexicon
t_example = NRCLex('Because the greatest love of all is happening to me. I found the greatest love of all inside of me')
aff_dict_example = t_example.affect_frequencies
try: 
    aff_dict_example['anticip'] = aff_dict_example['anticipation']
except: 
    pass
aff_dict_example.pop('anticipation', None)
aff_dict_example
# Out:
# {'fear': 0.18181818181818182,
#  'anger': 0.18181818181818182,
#  'anticip': 0.0,
#  'trust': 0.09090909090909091,
#  'surprise': 0.0,
#  'positive': 0.0,
#  'negative': 0.18181818181818182,
#  'sadness': 0.18181818181818182,
#  'disgust': 0.18181818181818182,
#  'joy': 0.0}

# %%
# spotify api setup and testing
# TERMINAL COMMANDS FOR SPOTIPY AUTH
# create env variables in conda base
# conda env config vars set SPOTIPY_CLIENT_ID='4469d6dd1a6748fb9284c88eb8bb8d31'
# conda env config vars set SPOTIPY_CLIENT_SECRET='9c58dc24df58489d847452384633b64b'
# conda env config vars set SPOTIPY_REDIRECT_URI='http://google.com/'
# list out the variables
# conda env config vars list

# initiate spotipy- spotify api python wrapper
auth_manager = SpotifyClientCredentials()
spot = spotipy.Spotify(auth_manager=auth_manager)

#testing- artist info
urn = 'spotify:artist:3jOstUTkEu2JkjvRdBA5Gu'
artist = spot.artist(urn)
print(artist)
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/3jOstUTkEu2JkjvRdBA5Gu'}, 'followers': {'href': None, 'total': 2454438}, 'genres': ['alternative rock', 'modern power pop', 'modern rock', 'permanent wave', 'rock'], 'href': 'https://api.spotify.com/v1/artists/3jOstUTkEu2JkjvRdBA5Gu', 'id': '3jOstUTkEu2JkjvRdBA5Gu', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebef2e09aeedd0d8f842d1a690', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174ef2e09aeedd0d8f842d1a690', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178ef2e09aeedd0d8f842d1a690', 'width': 160}], 'name': 'Weezer', 'popularity': 75, 'type': 'artist', 'uri': 'spotify:artist:3jOstUTkEu2JkjvRdBA5Gu'}

# %%
# Initialize Transformer- BERT Classifier
bert_cls = pipeline("text-classification",model= 'bhadresh-savani/albert-base-v2-emotion' , return_all_scores=True)
albert_column_names = ["sadness", "joy", "love", "anger", "fear", "surprise"]
albert_test_pred_raw = bert_cls("sunday morning rain is falling")
albert_test_pred_raw = albert_test_pred_raw[0]
albert_test_score_l = []
for score_label in albert_test_pred_raw:
    score = score_label['score']
    albert_test_score_l.append(score)
albert_test_score_l
# Out:
# [0.08749508857727051,
#  0.044749047607183456,
#  0.00836945790797472,
#  0.3867079019546509,
#  0.4656958281993866,
#  0.006982794962823391]

# %%
import billboard
chart = billboard.ChartData('hot-100')
# print(chart)

# %%
# simulate getting data from json
import json
with open("example_songs.json") as jfile:
    jdata = jfile.read()
    j_ex = json.loads(jdata)
dfj = pd.DataFrame(j_ex)

# %%
sdf = pd.DataFrame()
# raw lyrics data
lyrics_raw = []
# cleaned lyrics, each song's lyrics as a list of strings
lyrics_lines = []
# cleaned lyrics, each song's lyrics as one string
lyrics_string = []
# song titles
titles = []
# song artists
artists = []
# isrc numbers
isrcs = []


for i in range(len(j_ex['data'])):
    n = j_ex['data'][i]['attributes']['name']
    #shorten search query in genius due to limitation 
    n_short = re.sub(r'\(.*', '', n)
    a = j_ex['data'][i]['attributes']['artistName']
    isrc = j_ex['data'][i]['attributes']['isrc']
    try:
        song = genius.search_song(n_short, a)
        ly = song.lyrics
    except:
        ly = None
    lyrics_raw.append(ly)
    titles.append(n)
    artists.append(a)
    isrcs.append(isrc)
sdf['isrc'] = isrcs
sdf['title'] = titles
sdf['artist'] = artists
sdf['lyrics'] = lyrics_raw

# filter out the songs that have no lyrics
sdf = sdf.dropna()

# lyrics cleaning and spliting into list of lines

# lyrics cleaning

for lyrics in sdf['lyrics']:
    lyrics = re.sub(r'\n+', '\n', lyrics)
    lyrics = lyrics.replace('\n', '. ')
    lyrics = lyrics.replace('\u2005', '')
    lyrics = re.sub(r'\[[^\]]*\][.]', '', lyrics)
    # lyrics as one string
    ly_concat = lyrics
    lyrics_string.append(ly_concat)
    # return lines as list of strings
    ly_list = sent_tokenize(lyrics)
    lyrics_lines.append(ly_list)

sdf['lyrics_lines'] = lyrics_lines
sdf['lyrics_string'] = lyrics_string

# NRC emotional lexicon analysis
nrc_scores = []
for lines in sdf['lyrics_lines']:
    # nrc affection score list
    nrc_affection_freq_l = []
    for line in lines:
        nrc_txt = NRCLex(line)
        aff_dict = nrc_txt.affect_frequencies
  
        try: 
            aff_dict['anticip'] = aff_dict['anticipation']
        except: 
            pass
        
        aff_dict.pop('anticipation', None)

        affection_freq = list(aff_dict.values())
    

        # print(affection_freq)
        nrc_affection_freq_l.append(affection_freq)
        # affection_freq_arr = np.append(affection_freq_arr, np.array([affection_freq]), axis=0)

    ly_aff_arr = np.array(nrc_affection_freq_l)
    nrc_score = np.sum(ly_aff_arr, axis=0)
    nrc_scores.append(nrc_score)

sdf['nrc_score'] = nrc_scores


# Vader
vader_sent = SentimentIntensityAnalyzer()
# vader scores based on string
sdf['str_vader_score'] = sdf['lyrics_string'].apply(lambda lyrics: vader_sent.polarity_scores(lyrics))

# vader scores based on lines
line_vader_scores = []
for lines in sdf['lyrics_lines']:
    # nrc affection score list
    vader_score_l = []
    for line in lines:
        line_vader_score = vader_sent.polarity_scores(line)
        line_vader_score = list(line_vader_score.values())
        vader_score_l.append(line_vader_score)

    ly_vad_arr = np.array(vader_score_l)
    vader_score = np.sum(ly_vad_arr, axis=0)
    line_vader_scores.append(vader_score)

sdf['line_vader_score'] = line_vader_scores

# Spotify audio feature/ analysis
spot_audio_analysis = []
spot_audio_features = []
for idx, song in sdf.iterrows():
    title = song['title']
    # in case
    t_short = re.sub(r'\(.*', '', title)
    isrc = song['isrc']
    artist = song['artist']
    ### REMINDER: ISRC SEARCH METHOD IS NOT STABLE AS SOME ISRC CODES PROVIDED BY APPLE MAY BE OUTDATED THUS COULD NOT BE USED ###
    # spot_track_obj = sp.search(q='isrc:' + isrc, type='track')
    try:
        spot_track_obj = spot.search(q='isrc:' + isrc, type='track')
        spot_track_id = spot_track_obj['tracks']['items'][0]['id']
        spot_ana = spot.audio_analysis(spot_track_id)
        spot_feat = spot.audio_features(tracks=[spot_track_id])
    except:
        try:
            spot_track_obj = spot.search(q='artist:' + artist + ' track:' + t_short, type='track')
            spot_track_id = spot_track_obj['tracks']['items'][0]['id']
            spot_ana = spot.audio_analysis(spot_track_id)
            spot_feat = spot.audio_features(tracks=[spot_track_id])
        except:
            spot_ana = None
            spot_feat = None
    

    spot_audio_analysis.append(spot_ana)
    spot_audio_features.append(spot_feat[0])

sdf['spot_audio_analysis'] = spot_audio_analysis
sdf['spot_audio_features'] = spot_audio_features

# BERT- ALBERT pretrained model
#TODO: albert scores based on string
#str_albert_scores = []
#for lyrics in sdf['lyrics_string']:
    #albert_pred_raw  = bert_cls(lyrics)
    #albert_score = [score_label['score'] for score_label in albert_pred_raw[0]]
    #str_albert_scores.append(albert_score)
#sdf['str_albert_score'] = str_albert_scores

# albert scores based on lines
line_albert_scores = []
for lines in sdf['lyrics_lines']:

    albert_score_l = []
    for line in lines:
        albert_pred_raw = bert_cls(line)
        albert_pred_raw = albert_pred_raw[0]
        albert_l = [score_label['score'] for score_label in albert_pred_raw]
        albert_score_l.append(albert_l)
    ly_albert_arr = np.array(albert_score_l)
    albert_score = np.sum(ly_albert_arr, axis=0)
    line_albert_scores.append(albert_score)

sdf['line_albert_score'] = line_albert_scores
# Out:
# Searching for "Enchanted" by Taylor Swift...
# Done.
# Searching for "Empire State of Mind " by JAY-Z & Alicia Keys...
# Done.
# Searching for "24K Magic" by Bruno Mars...
# Done.
# Searching for "Sucker for Pain " by Lil Wayne, Wiz Khalifa & Imagine Dragons...
# Done.
# Searching for "Someone You Loved" by Lewis Capaldi...
# Done.

# %%
# break down score lists/ dicts from sdf

#nrc
nrc_std_dict = {'fear': 0.0, 'anger': 0.0, 'anticipation': 0.0, 'trust': 0.0, 'surprise': 0.0,'positive': 0.0,'negative': 0.0,'sadness': 0.0,'disgust': 0.0,'joy': 0.0}

nrc_fear = [nrc_score[0] for nrc_score in sdf['nrc_score']]
nrc_anger = [nrc_score[1] for nrc_score in sdf['nrc_score']]
nrc_anticipation = [nrc_score[2] for nrc_score in sdf['nrc_score']]
nrc_trust = [nrc_score[3] for nrc_score in sdf['nrc_score']]
nrc_surprise = [nrc_score[4] for nrc_score in sdf['nrc_score']]
nrc_positive = [nrc_score[5] for nrc_score in sdf['nrc_score']]
nrc_negative = [nrc_score[6] for nrc_score in sdf['nrc_score']]
nrc_sadness = [nrc_score[7] for nrc_score in sdf['nrc_score']]
nrc_disgust = [nrc_score[8] for nrc_score in sdf['nrc_score']]
nrc_joy = [nrc_score[9] for nrc_score in sdf['nrc_score']]

#vader
vader_dict = {'neg': 0.073, 'neu': 0.791, 'pos': 0.137, 'compound': 0.9706}

line_vader_neg = [line_vader_score[0] for line_vader_score in sdf['line_vader_score']]
line_vader_neu = [line_vader_score[1] for line_vader_score in sdf['line_vader_score']]
line_vader_pos = [line_vader_score[2] for line_vader_score in sdf['line_vader_score']]
line_vader_compound = [line_vader_score[3] for line_vader_score in sdf['line_vader_score']]

vader_str_df = sdf.str_vader_score.dropna().apply(pd.Series)
str_vader_neg = vader_str_df[vader_str_df.columns[0]]
str_vader_neu = vader_str_df[vader_str_df.columns[1]]
str_vader_pos = vader_str_df[vader_str_df.columns[2]]
str_vader_compound = vader_str_df[vader_str_df.columns[3]]

#spotify

spot_audio_ft_dict = {'danceability': 0, 'energy': 0, 'key': 0, 'loudness': 0, 'mode': 0, 'speechiness': 0,'acousticness': 0,'instrumentalness': 0,'liveness': 0,'valence': 0,'tempo': 0,'type': 'audio_features','id': 'id','uri': 'spotifyuri','track_href': 'url','analysis_url': 'url','duration_ms': 0,'time_signature': 0}

spot_audio_ana_df = sdf.spot_audio_analysis.dropna().apply(pd.Series)
spot_audio_ft_df = sdf.spot_audio_features.dropna().apply(pd.Series)
spot_danceability = spot_audio_ft_df[spot_audio_ft_df.columns[0]]
spot_energy = spot_audio_ft_df[spot_audio_ft_df.columns[1]]
spot_key = spot_audio_ft_df[spot_audio_ft_df.columns[2]]
spot_loudness = spot_audio_ft_df[spot_audio_ft_df.columns[3]]
spot_mode = spot_audio_ft_df[spot_audio_ft_df.columns[4]]
spot_speechiness = spot_audio_ft_df[spot_audio_ft_df.columns[5]]
spot_acousticness = spot_audio_ft_df[spot_audio_ft_df.columns[6]]
spot_instrumentalness = spot_audio_ft_df[spot_audio_ft_df.columns[7]]
spot_liveness = spot_audio_ft_df[spot_audio_ft_df.columns[8]]
spot_valence = spot_audio_ft_df[spot_audio_ft_df.columns[9]]
spot_tempo = spot_audio_ft_df[spot_audio_ft_df.columns[10]]

#bert
albert_column_names = ["sadness", "joy", "love", "anger", "fear", "surprise"]

line_albert_sadness = [line_albert_score[0] for line_albert_score in sdf['line_albert_score']]
line_albert_joy = [line_albert_score[1] for line_albert_score in sdf['line_albert_score']]
line_albert_love = [line_albert_score[2] for line_albert_score in sdf['line_albert_score']]
line_albert_anger = [line_albert_score[3] for line_albert_score in sdf['line_albert_score']]
line_albert_fear = [line_albert_score[4] for line_albert_score in sdf['line_albert_score']]
line_albert_surprise = [line_albert_score[5] for line_albert_score in sdf['line_albert_score']]

# %%
sdf
# Out:
#            isrc                                              title  \
# 0  USCJY1003663                                          Enchanted
# 1  USJZ10900031           Empire State of Mind (feat. Alicia Keys)
# 2  USAT21602945                                          24K Magic
# 3  USAT21601891  Sucker for Pain (with Logic, Ty Dolla $ign & X...
# 4  DEUM71807062                                  Someone You Loved
#
#                                      artist  \
# 0                              Taylor Swift
# 1                       JAY-Z & Alicia Keys
# 2                                Bruno Mars
# 3  Lil Wayne, Wiz Khalifa & Imagine Dragons
# 4                             Lewis Capaldi
#
#                                               lyrics  \
# 0  [Verse 1]\nThere I was again tonight\nForcing ...
# 1  [Intro: JAY-Z]\nYeah\n\n[Verse 1: Jay-Z]\nYeah...
# 2  [Intro]\nTonight\nI just want to take you high...
# 3  [Chorus: Dan Reynolds & Sam Harris]\nI torture...
# 4  [Verse 1]\nI'm going under, and this time, I f...
#
#                                         lyrics_lines  \
# 0  [ There I was again tonight., Forcing laughter...
# 1  [ Yeah., Yeah, I'm out that Brooklyn, now I'm ...
# 2  [ Tonight., I just want to take you higher., T...
# 3  [ I torture you., Take my hand through the fla...
# 4  [ I'm going under, and this time, I fear there...
#
#                                        lyrics_string  \
# 0   There I was again tonight. Forcing laughter, ...
# 1   Yeah.  Yeah, I'm out that Brooklyn, now I'm d...
# 2   Tonight. I just want to take you higher. Thro...
# 3   I torture you. Take my hand through the flame...
# 4   I'm going under, and this time, I fear there'...
#
#                                            nrc_score  \
# 0  [0.16666666666666666, 0.8666666666666667, 1.24...
# 1  [6.633333333333334, 2.216666666666667, 3.13571...
# 2  [1.453088578088578, 2.143997668997669, 3.32616...
# 3  [9.367532467532472, 6.400865800865802, 4.27543...
# 4  [2.7595238095238095, 0.6428571428571428, 0.592...
#
#                                      str_vader_score  \
# 0  {'neg': 0.073, 'neu': 0.791, 'pos': 0.137, 'co...
# 1  {'neg': 0.053, 'neu': 0.794, 'pos': 0.153, 'co...
# 2  {'neg': 0.09, 'neu': 0.826, 'pos': 0.083, 'com...
# 3  {'neg': 0.251, 'neu': 0.652, 'pos': 0.098, 'co...
# 4  {'neg': 0.078, 'neu': 0.795, 'pos': 0.127, 'co...
#
#                                     line_vader_score  \
# 0  [3.5860000000000003, 63.21900000000001, 8.195,...
# 1  [2.9910000000000005, 75.78600000000002, 10.222...
# 2  [4.1819999999999995, 82.305, 6.513999999999999...
# 3  [21.627, 51.77199999999999, 7.6000000000000005...
# 4  [1.645, 28.541000000000004, 2.814, 1.338300000...
#
#                                  spot_audio_analysis  \
# 0  {'meta': {'analyzer_version': '4.0.0', 'platfo...
# 1  {'meta': {'analyzer_version': '4.0.0', 'platfo...
# 2  {'meta': {'analyzer_version': '4.0.0', 'platfo...
# 3  {'meta': {'analyzer_version': '4.0.0', 'platfo...
# 4  {'meta': {'analyzer_version': '4.0.0', 'platfo...
#
#                                  spot_audio_features  \
# 0  {'danceability': 0.455, 'energy': 0.623, 'key'...
# 1  {'danceability': 0.491, 'energy': 0.956, 'key'...
# 2  {'danceability': 0.818, 'energy': 0.803, 'key'...
# 3  {'danceability': 0.502, 'energy': 0.786, 'key'...
# 4  {'danceability': 0.501, 'energy': 0.405, 'key'...
#
#                                    line_albert_score
# 0  [4.637160549988039, 36.223811578936875, 4.9320...
# 1  [4.01865521655418, 34.90297035779804, 3.149679...
# 2  [4.3135047677205876, 31.08296650776174, 2.8674...
# 3  [5.4936684526037425, 15.897402132453863, 4.477...
# 4  [3.227711145300418, 8.306011193897575, 6.43257...

# %%
vader_dict = {'neg': 0.073, 'neu': 0.791, 'pos': 0.137, 'compound': 0.9706}

sdf['str_vader_score'][0]
# Out:
# {'neg': 0.073, 'neu': 0.791, 'pos': 0.137, 'compound': 0.9706}

# %%
nrc_std_dict = {'fear': 0.0, 'anger': 0.0, 'anticipation': 0.0, 'trust': 0.0, 'surprise': 0.0,'positive': 0.0,'negative': 0.0,'sadness': 0.0,'disgust': 0.0,'joy': 0.0}
sdf["nrc_score"][0]
# Out:
# array([0.16666667, 0.86666667, 1.25      , 2.7       , 0.95      ,
#        7.45      , 1.83333333, 0.16666667, 0.16666667, 6.45      ])

# %%
albert_column_names = ["sadness", "joy", "love", "anger", "fear", "surprise"]
sdf["line_albert_score"][0]
# Out:
# array([ 4.63716055, 36.22381158,  4.93201505, 17.93599799,  9.79658638,
#         1.47442829])

# %%
sdf["spot_audio_features"][0]
# Out:
# [{'danceability': 0.455,
#   'energy': 0.623,
#   'key': 8,
#   'loudness': -3.878,
#   'mode': 1,
#   'speechiness': 0.0288,
#   'acousticness': 0.0739,
#   'instrumentalness': 0.000424,
#   'liveness': 0.146,
#   'valence': 0.208,
#   'tempo': 163.893,
#   'type': 'audio_features',
#   'id': '10eBRyImhfqVvkiVEGf0N0',
#   'uri': 'spotify:track:10eBRyImhfqVvkiVEGf0N0',
#   'track_href': 'https://api.spotify.com/v1/tracks/10eBRyImhfqVvkiVEGf0N0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/10eBRyImhfqVvkiVEGf0N0',
#   'duration_ms': 352187,
#   'time_signature': 4}]

# %%
sdf["spot_audio_analysis"][0]
# Out:
# {'meta': {'analyzer_version': '4.0.0',
#   'platform': 'Linux',
#   'detailed_status': 'OK',
#   'status_code': 0,
#   'timestamp': 1571899455,
#   'analysis_time': 11.95495,
#   'input_process': 'libvorbisfile L+R 44100->22050'},
#  'track': {'num_samples': 7765716,
#   'duration': 352.18668,
#   'sample_md5': '',
#   'offset_seconds': 0,
#   'window_seconds': 0,
#   'analysis_sample_rate': 22050,
#   'analysis_channels': 1,
#   'end_of_fade_in': 2.53098,
#   'start_of_fade_out': 345.0195,
#   'loudness': -3.878,
#   'tempo': 163.893,
#   'tempo_confidence': 0.085,
#   'time_signature': 4,
#   'time_signature_confidence': 1.0,
#   'key': 8,
#   'key_confidence': 0.747,
#   'mode': 1,
#   'mode_confidence': 0.802,
#   'codestring': 'eJxVmwlyJDkOBL9ST-B9_P9j4x4sqTW2ZrNNViaTBIFA4NCptd_dz_mUz1m31N7L-dT1RuvO3T_9jO9otfOZY3xuG2uMOhfz-a22fkv51MJC30dPZZnePidfuON8Wqnrz0faKH-_0vb838OX7zgc1a_2Wn6G2dLg27wwamvVDfLt02abu9TPaG18Zpnlnjs_Y-7FqJ9y9_iMy9EyOnxk9tr-jBaHuZ3trcr8Ks55sosA1sj5xhi97j4_y-129nPn4pfNS5_OvysLMBzHA9Y5z2ns9Ozmr3PcMu7nuMH3654IzB3egwCQO78eFmij1d7q5dfL8es597Cxzf5qlhp379I-d-UCzirb66jFTT8p8gTjjtwab0-ugu3nQsqc
#   {'start': 12.31216, 'duration': 1.46779, 'confidence': 0.424},
#   {'start': 13.77995, 'duration': 1.47467, 'confidence': 0.034},
#   {'start': 15.25462, 'duration': 1.47698, 'confidence': 0.512},
#   {'start': 16.7316, 'duration': 1.44963, 'confidence': 0.641},
#   {'start': 18.18123, 'duration': 1.45786, 'confidence': 0.156},
#   {'start': 19.63909, 'duration': 1.46922, 'confidence': 0.224},
#   {'start': 21.10831, 'duration': 1.45924, 'confidence': 0.3},
#   {'start': 22.56755, 'duration': 1.4544, 'confidence': 0.327},
#   {'start': 24.02195, 'duration': 1.47374, 'confidence': 0.646},
#   {'start': 25.49569, 'duration': 1.48506, 'confidence': 0.467},
#   {'start': 26.98076, 'duration': 1.46052, 'confidence': 0.712},
#   {'start': 28.44128, 'duration': 1.45764, 'confidence': 0.222},
#   {'start': 29.89892, 'duration': 1.472, 'confidence': 0.215},
#   {'start': 31.37093, 'duration': 1.47379, 'confidence': 0.303},
#   {'start': 32.84472, 'duration': 1.45494, 'confidence': 0.488},
#   {'start': 34.29966, 'duration': 1.45811, 'confidence': 0.737},
#   {'start': 35.75777, 'duration': 1.46383, 'confidence': 0.11},
#   {'start': 37.2216, 'duration': 1.46219, 'confidence': 0.268},
#   {'start': 38.6838, 'duration': 1.45256, 'confidence': 0.199},
#   {'start': 40.13636, 'duration': 1.45853, 'confidence': 0.462},
#   {'start': 41.59489, 'duration': 1.46491, 'confidence': 0.269},
#   {'start': 43.0598, 'duration': 1.4642, 'confidence': 0.622},
#   {'start': 44.524, 'duration': 1.46602, 'confidence': 0.532},
#   {'start': 45.99002, 'duration': 1.46178, 'confidence': 0.557},
#   {'start': 47.4518, 'duration': 1.46767, 'confidence': 0.232},
#   {'start': 48.91947, 'duration': 1.47327, 'confidence': 0.185},
#   {'start': 50.39274, 'duration': 1.46663, 'confidence': 0.241},
#   {'start': 51.85937, 'duration': 1.46807, 'confidence': 0.74},
#   {'start': 53.32743, 'duration': 1.46977, 'confidence': 0.283},
#   {'start': 54.7972, 'duration': 1.45382, 'confidence': 0.063},
#   {'start': 56.25102, 'duration': 1.4552, 'confidence': 0.379},
#   {'start': 57.70623, 'duration': 1.45229, 'confidence': 0.699},
#   {'start': 59.15851, 'duration': 1.47728, 'confidence': 0.163},
#   {'start': 60.6358, 'duration': 1.4769, 'confidence': 0.392},
#   {'start': 62.1127, 'duration': 1.45151, 'confidence': 0.784},
#   {'start': 63.56421, 'duration': 1.43636, 'confidence': 0.31},
#   {'start': 65.00057, 'duration': 1.46429, 'confidence': 0.689},
#   {'start': 66.46486, 'duration': 1.48806, 'confidence': 0.661},
#   {'start': 67.95292, 'duration': 1.47165, 'confidence': 0.197},
#   {'start': 69.42456, 'duration': 1.46294, 'confidence': 0.552},
#   {'start': 70.88751, 'duration': 1.46914, 'confidence': 0.604},
#   {'start': 72.35665, 'duration': 1.46425, 'confidence': 0.268},
#   {'start': 73.8209, 'duration': 1.45469, 'confidence': 0.526},
#   {'start': 75.27559, 'duration': 1.45888, 'confidence': 0.793},
#   {'start': 76.73447, 'duration': 1.46164, 'confidence': 0.516},
#   {'start': 78.19612, 'duration': 1.4626, 'confidence': 0.458},
#   {'start': 79.65872, 'duration': 1.4591, 'confidence': 0.038},
#   {'start': 81.11782, 'duration': 1.46841, 'confidence': 0.041},
#   {'start': 82.58623, 'duration': 1.47081, 'confidence': 0.386},
#   {'start': 84.05704, 'duration': 1.47158, 'confidence': 0.263},
#   {'start': 85.52863, 'duration': 1.45796, 'confidence': 0.442},
#   {'start': 86.98658, 'duration': 1.45685, 'confidence': 0.433},
#   {'start': 88.44343, 'duration': 1.46308, 'confidence': 0.2},
#   {'start': 89.90652, 'duration': 1.45631, 'confidence': 0.522},
#   {'start': 91.36283, 'duration': 1.45226, 'confidence': 0.398},
#   {'start': 92.81509, 'duration': 1.45287, 'confidence': 0.709},
#   {'start': 94.26796, 'duration': 1.47252, 'confidence': 0.273},
#   {'start': 95.74047, 'duration': 1.4775, 'confidence': 0.76},
#   {'start': 97.21797, 'duration': 1.47529, 'confidence': 0.496},
#   {'start': 98.69327, 'duration': 1.47694, 'confidence': 0.404},
#   {'start': 100.1702, 'duration': 1.43576, 'confidence': 0.166},
#   {'start': 101.60597, 'duration': 1.47023, 'confidence': 0.514},
#   {'start': 103.0762, 'duration': 1.48174, 'confidence': 0.595},
#   {'start': 104.55794, 'duration': 1.45937, 'confidence': 0.721},
#   {'start': 106.01731, 'duration': 1.44465, 'confidence': 0.601},
#   {'start': 107.46196, 'duration': 1.47131, 'confidence': 0.675},
#   {'start': 108.93327, 'duration': 1.47811, 'confidence': 0.68},
#   {'start': 110.41137, 'duration': 1.45554, 'confidence': 0.667},
#   {'start': 111.86691, 'duration': 1.46589, 'confidence': 0.22},
#   {'start': 113.33281, 'duration': 1.46642, 'confidence': 0.426},
#   {'start': 114.79922, 'duration': 1.42914, 'confidence': 0.609},
#   {'start': 116.22836, 'duration': 1.42883, 'confidence': 0.089},
#   {'start': 117.65719, 'duration': 1.43375, 'confidence': 0.323},
#   {'start': 119.09094, 'duration': 1.49197, 'confidence': 0.874},
#   {'start': 120.58291, 'duration': 1.51211, 'confidence': 0.833},
#   {'start': 122.09502, 'duration': 1.46477, 'confidence': 0.751},
#   {'start': 123.5598, 'duration': 1.46261, 'confidence': 0.517},
#   {'start': 125.02241, 'duration': 1.466, 'confidence': 0.211},
#   {'start': 126.48841, 'duration': 1.468, 'confidence': 0.867},
#   {'start': 127.95641, 'duration': 1.46606, 'confidence': 0.66},
#   {'start': 129.42247, 'duration': 1.46888, 'confidence': 0.506},
#   {'start': 130.89136, 'duration': 1.46039, 'confidence': 0.516},
#   {'start': 132.35173, 'duration': 1.47181, 'confidence': 0.639},
#   {'start': 133.82355, 'duration': 2.56183, 'confidence': 0.504},
#   {'start': 136.38538, 'duration': 1.45986, 'confidence': 0.886},
#   {'start': 137.84525, 'duration': 1.46746, 'confidence': 0.468},
#   {'start': 139.3127, 'duration': 1.45851, 'confidence': 0.59},
#   {'start': 140.77121, 'duration': 1.46556, 'confidence': 0.438},
#   {'start': 142.23677, 'duration': 1.46114, 'confidence': 0.704},
#   {'start': 143.6979, 'duration': 1.46683, 'confidence': 0.347},
#   {'start': 145.16473, 'duration': 1.465, 'confidence': 0.765},
#   {'start': 146.62975, 'duration': 1.46266, 'confidence': 0.596},
#   {'start': 148.0924, 'duration': 1.46205, 'confidence': 0.621},
#   {'start': 149.55444, 'duration': 1.4611, 'confidence': 0.558},
#   {'start': 151.01555, 'duration': 1.45796, 'confidence': 0.704},
#   {'start': 152.47351, 'duration': 1.45997, 'confidence': 0.392},
#   {'start': 153.93349, 'duration': 1.46869, 'confidence': 0.615},
#   {'start': 155.40218, 'duration': 1.46826, 'confidence': 0.445},
#   {'start': 156.87044, 'duration': 1.45758, 'confidence': 0.038},
#   {'start': 158.328, 'duration': 1.46139, 'confidence': 0.107},
#   {'start': 159.7894, 'duration': 1.47458, 'confidence': 0.896},
#   {'start': 161.26398, 'duration': 1.46383, 'confidence': 0.421},
#   {'start': 162.72781, 'duration': 1.46127, 'confidence': 0.754},
#   {'start': 164.18909, 'duration': 1.09818, 'confidence': 0.465},
#   {'start': 165.28726, 'duration': 1.45732, 'confidence': 0.533},
#   {'start': 166.74458, 'duration': 1.46779, 'confidence': 0.683},
#   {'start': 168.21239, 'duration': 1.4596, 'confidence': 0.406},
#   {'start': 169.67198, 'duration': 1.45968, 'confidence': 0.339},
#   {'start': 171.13165, 'duration': 1.46294, 'confidence': 0.247},
#   {'start': 172.5946, 'duration': 1.47264, 'confidence': 0.254},
#   {'start': 174.06725, 'duration': 0.73531, 'confidence': 0.824},
#   {'start': 174.80255, 'duration': 1.47661, 'confidence': 0.554},
#   {'start': 176.27914, 'duration': 1.45933, 'confidence': 0.295},
#   {'start': 177.73848, 'duration': 1.45703, 'confidence': 0.869},
#   {'start': 179.19551, 'duration': 1.47755, 'confidence': 0.392},
#   {'start': 180.67307, 'duration': 1.46373, 'confidence': 0.639},
#   {'start': 182.1368, 'duration': 1.45719, 'confidence': 0.684},
#   {'start': 183.59398, 'duration': 1.4512, 'confidence': 0.542},
#   {'start': 185.0452, 'duration': 1.45963, 'confidence': 0.585},
#   {'start': 186.50482, 'duration': 1.47891, 'confidence': 0.584},
#   {'start': 187.98373, 'duration': 1.46079, 'confidence': 0.338},
#   {'start': 189.4445, 'duration': 1.46758, 'confidence': 0.605},
#   {'start': 190.9121, 'duration': 1.47936, 'confidence': 0.706},
#   {'start': 192.39145, 'duration': 1.44691, 'confidence': 0.774},
#   {'start': 193.83836, 'duration': 1.46251, 'confidence': 0.093},
#   {'start': 195.30087, 'duration': 1.46264, 'confidence': 0.234},
#   {'start': 196.7635, 'duration': 1.49302, 'confidence': 0.501},
#   {'start': 198.25653, 'duration': 2.55322, 'confidence': 0.81},
#   {'start': 200.80975, 'duration': 1.44121, 'confidence': 0.853},
#   {'start': 202.25096, 'duration': 1.46591, 'confidence': 0.659},
#   {'start': 203.71687, 'duration': 1.47858, 'confidence': 0.61},
#   {'start': 205.19545, 'duration': 1.46517, 'confidence': 0.295},
#   {'start': 206.66061, 'duration': 1.44996, 'confidence': 0.075},
#   {'start': 208.11058, 'duration': 1.45584, 'confidence': 0.48},
#   {'start': 209.56642, 'duration': 1.46701, 'confidence': 0.567},
#   {'start': 211.03342, 'duration': 1.4731, 'confidence': 0.635},
#   {'start': 212.50652, 'duration': 1.47428, 'confidence': 0.705},
#   {'start': 213.9808, 'duration': 1.46509, 'confidence': 0.901},
#   {'start': 215.44589, 'duration': 1.44019, 'confidence': 0.74},
#   {'start': 216.8861, 'duration': 1.46168, 'confidence': 0.411},
#   {'start': 218.34776, 'duration': 0.74011, 'confidence': 0.183},
#   {'start': 219.08788, 'duration': 1.47045, 'confidence': 0.664},
#   {'start': 220.55833, 'duration': 1.45115, 'confidence': 0.548},
#   {'start': 222.00948, 'duration': 1.45581, 'confidence': 0.53},
#   {'start': 223.46529, 'duration': 1.47637, 'confidence': 0.38},
#   {'start': 224.94167, 'duration': 1.45541, 'confidence': 0.736},
#   {'start': 226.39706, 'duration': 1.4608, 'confidence': 0.179},
#   {'start': 227.85786, 'duration': 1.48585, 'confidence': 0.577},
#   {'start': 229.34373, 'duration': 1.4868, 'confidence': 0.347},
#   {'start': 230.83054, 'duration': 1.4547, 'confidence': 0.764},
#   {'start': 232.28523, 'duration': 1.45326, 'confidence': 0.181},
#   {'start': 233.7385, 'duration': 1.44915, 'confidence': 0.429},
#   {'start': 235.18764, 'duration': 1.47056, 'confidence': 0.289},
#   {'start': 236.6582, 'duration': 1.46058, 'confidence': 0.748},
#   {'start': 238.11879, 'duration': 1.45803, 'confidence': 0.367},
#   {'start': 239.57681, 'duration': 1.46842, 'confidence': 0.634},
#   {'start': 241.04524, 'duration': 1.4725, 'confidence': 0.642},
#   {'start': 242.51775, 'duration': 1.4661, 'confidence': 0.681},
#   {'start': 243.98384, 'duration': 1.46467, 'confidence': 0.658},
#   {'start': 245.44852, 'duration': 1.45821, 'confidence': 0.356},
#   {'start': 246.90672, 'duration': 1.46807, 'confidence': 0.496},
#   {'start': 248.37479, 'duration': 1.46873, 'confidence': 0.772},
#   {'start': 249.84352, 'duration': 1.46219, 'confidence': 0.736},
#   {'start': 251.3057, 'duration': 1.46066, 'confidence': 0.548},
#   {'start': 252.76637, 'duration': 1.47068, 'confidence': 0.39},
#   {'start': 254.23705, 'duration': 1.45522, 'confidence': 0.513},
#   {'start': 255.69228, 'duration': 1.09156, 'confidence': 0.558},
#   {'start': 256.78384, 'duration': 1.47143, 'confidence': 0.303},
#   {'start': 258.25525, 'duration': 1.49155, 'confidence': 0.646},
#   {'start': 259.7468, 'duration': 1.4712, 'confidence': 0.722},
#   {'start': 261.21802, 'duration': 1.42548, 'confidence': 0.846},
#   {'start': 262.6435, 'duration': 1.45696, 'confidence': 0.495},
#   {'start': 264.10046, 'duration': 1.46834, 'confidence': 0.287},
#   {'start': 265.5688, 'duration': 1.4642, 'confidence': 0.68},
#   {'start': 331.44138, 'duration': 1.44563, 'confidence': 0.381},
#   {'start': 332.887, 'duration': 1.46097, 'confidence': 0.287},
#   {'start': 334.34796, 'duration': 1.46504, 'confidence': 0.109},
#   {'start': 335.81302, 'duration': 1.47242, 'confidence': 0.836},
#   {'start': 337.28543, 'duration': 1.46687, 'confidence': 0.296},
#   {'start': 338.75232, 'duration': 1.45596, 'confidence': 0.316},
#   {'start': 340.20825, 'duration': 1.46649, 'confidence': 0.496},
#   {'start': 341.67477, 'duration': 1.48243, 'confidence': 0.685},
#   {'start': 343.1572, 'duration': 1.47833, 'confidence': 0.124},
#   {'start': 344.63553, 'duration': 1.46563, 'confidence': 0.301},
#   {'start': 346.10114, 'duration': 1.88426, 'confidence': 0.45}],
#  'beats': [{'start': 0.60386, 'duration': 0.3845, 'confidence': 0.319},
#   {'start': 0.98836, 'duration': 0.36009, 'confidence': 0.209},
#   {'start': 1.34846, 'duration': 0.36214, 'confidence': 0.139},
#   {'start': 1.7106, 'duration': 0.36575, 'confidence': 0.686},
#   {'start': 2.07634, 'duration': 0.36346, 'confidence': 0.701},
#   {'start': 2.4398, 'duration': 0.35855, 'confidence': 0.776},
#   {'start': 2.79836, 'duration': 0.36509, 'confidence': 0.829},
#   {'start': 3.16345, 'duration': 0.36674, 'confidence': 0.839},
#   {'start': 3.53018, 'duration': 0.36707, 'confidence': 0.844},
#   {'start': 3.89726, 'duration': 0.36644, 'confidence': 0.852},
#   {'start': 4.26369, 'duration': 0.36579, 'confidence': 0.841},
#   {'start': 4.62949, 'duration': 0.36615, 'confidence': 0.813},
#   {'start': 4.99564, 'duration': 0.36618, 'confidence': 0.802},
#   {'start': 5.36182, 'duration': 0.36588, 'confidence': 0.809},
#   {'start': 5.72769, 'duration': 0.36593, 'confidence': 0.788},
#   {'start': 6.09362, 'duration': 0.36597, 'confidence': 0.795},
#   {'start': 6.45959, 'duration': 0.36634, 'confidence': 0.782},
#   {'start': 6.82593, 'duration': 0.36616, 'confidence': 0.78},
#   {'start': 7.19209, 'duration': 0.36572, 'confidence': 0.78},
#   {'start': 7.55781, 'duration': 0.36561, 'confidence': 0.766},
#   {'start': 7.92342, 'duration': 0.36485, 'confidence': 0.774},
#   {'start': 8.28827, 'duration': 0.36409, 'confidence': 0.776},
#   {'start': 8.65236, 'duration': 0.36431, 'confidence': 0.724},
#   {'start': 9.01667, 'duration': 0.36586, 'confidence': 0.716},
#   {'start': 9.38252, 'duration': 0.36598, 'confidence': 0.716},
#   {'start': 9.7485, 'duration': 0.36569, 'confidence': 0.729},
#   {'start': 10.11419, 'duration': 0.3654, 'confidence': 0.726},
#   {'start': 10.4796, 'duration': 0.3661, 'confidence': 0.732},
#   {'start': 10.84569, 'duration': 0.36677, 'confidence': 0.772},
#   {'start': 11.21246, 'duration': 0.36613, 'confidence': 0.778},
#   {'start': 11.57859, 'duration': 0.36515, 'confidence': 0.778},
#   {'start': 11.94373, 'duration': 0.36842, 'confidence': 0.757},
#   {'start': 28.07943, 'duration': 0.36185, 'confidence': 0.557},
#   {'start': 28.44128, 'duration': 0.36382, 'confidence': 0.621},
#   {'start': 28.8051, 'duration': 0.36382, 'confidence': 0.596},
#   {'start': 29.16892, 'duration': 0.36448, 'confidence': 0.362},
#   {'start': 29.53339, 'duration': 0.36553, 'confidence': 0.362},
#   {'start': 29.89892, 'duration': 0.36658, 'confidence': 0.362},
#   {'start': 30.26551, 'duration': 0.36764, 'confidence': 0.362},
#   {'start': 30.63314, 'duration': 0.36869, 'confidence': 0.362},
#   {'start': 31.00184, 'duration': 0.36909, 'confidence': 0.362},
#   {'start': 31.37093, 'duration': 0.37038, 'confidence': 0.455},
#   {'start': 31.7413, 'duration': 0.36936, 'confidence': 0.44},
#   {'start': 32.11066, 'duration': 0.3677, 'confidence': 0.374},
#   {'start': 32.47836, 'duration': 0.36636, 'confidence': 0.331},
#   {'start': 32.84472, 'duration': 0.36599, 'confidence': 0.203},
#   {'start': 33.21071, 'duration': 0.36367, 'confidence': 0.342},
#   {'start': 33.57439, 'duration': 0.36331, 'confidence': 0.242},
#   {'start': 33.9377, 'duration': 0.36196, 'confidence': 0.2},
#   {'start': 34.29966, 'duration': 0.36325, 'confidence': 0.559},
#   {'start': 34.66291, 'duration': 0.36683, 'confidence': 0.535},
#   {'start': 35.02974, 'duration': 0.36386, 'confidence': 0.598},
#   {'start': 35.3936, 'duration': 0.36417, 'confidence': 0.598},
#   {'start': 35.75777, 'duration': 0.36252, 'confidence': 0.438},
#   {'start': 36.12029, 'duration': 0.36448, 'confidence': 0.295},
#   {'start': 36.48477, 'duration': 0.36743, 'confidence': 0.209},
#   {'start': 36.8522, 'duration': 0.3694, 'confidence': 0.24},
#   {'start': 37.2216, 'duration': 0.36546, 'confidence': 0.172},
#   {'start': 37.58706, 'duration': 0.36547, 'confidence': 0.139},
#   {'start': 37.95253, 'duration': 0.36547, 'confidence': 0.474},
#   {'start': 38.318, 'duration': 0.3658, 'confidence': 0.461},
#   {'start': 38.6838, 'duration': 0.36483, 'confidence': 0.413},
#   {'start': 39.04863, 'duration': 0.36419, 'confidence': 0.366},
#   {'start': 39.41282, 'duration': 0.36126, 'confidence': 0.41},
#   {'start': 39.77408, 'duration': 0.36227, 'confidence': 0.308},
#   {'start': 40.13636, 'duration': 0.36525, 'confidence': 0.438},
#   {'start': 40.5016, 'duration': 0.36232, 'confidence': 0.392},
#   {'start': 40.86392, 'duration': 0.36563, 'confidence': 0.348},
#   {'start': 41.22956, 'duration': 0.36533, 'confidence': 0.286},
#   {'start': 41.59489, 'duration': 0.36471, 'confidence': 0.269},
#   {'start': 41.95959, 'duration': 0.36572, 'confidence': 0.291},
#   {'start': 42.32532, 'duration': 0.36673, 'confidence': 0.24},
#   {'start': 42.69205, 'duration': 0.36776, 'confidence': 0.244},
#   {'start': 43.0598, 'duration': 0.36681, 'confidence': 0.23},
#   {'start': 43.42661, 'duration': 0.36455, 'confidence': 0.238},
#   {'start': 43.79116, 'duration': 0.36591, 'confidence': 0.21},
#   {'start': 59.89092, 'duration': 0.37175, 'confidence': 0.364},
#   {'start': 60.26267, 'duration': 0.37313, 'confidence': 0.492},
#   {'start': 60.6358, 'duration': 0.37121, 'confidence': 0.438},
#   {'start': 61.00701, 'duration': 0.37028, 'confidence': 0.332},
#   {'start': 61.37729, 'duration': 0.369, 'confidence': 0.269},
#   {'start': 61.74629, 'duration': 0.3664, 'confidence': 0.295},
#   {'start': 62.1127, 'duration': 0.36938, 'confidence': 0.32},
#   {'start': 62.48208, 'duration': 0.36345, 'confidence': 0.472},
#   {'start': 62.84553, 'duration': 0.36082, 'confidence': 0.445},
#   {'start': 63.20635, 'duration': 0.35785, 'confidence': 0.453},
#   {'start': 63.56421, 'duration': 0.35489, 'confidence': 0.337},
#   {'start': 63.91909, 'duration': 0.35621, 'confidence': 0.477},
#   {'start': 64.2753, 'duration': 0.36346, 'confidence': 0.354},
#   {'start': 64.63876, 'duration': 0.36181, 'confidence': 0.214},
#   {'start': 65.00057, 'duration': 0.35752, 'confidence': 0.325},
#   {'start': 65.3581, 'duration': 0.36049, 'confidence': 0.298},
#   {'start': 65.71859, 'duration': 0.36837, 'confidence': 0.231},
#   {'start': 66.08696, 'duration': 0.3779, 'confidence': 0.218},
#   {'start': 66.46486, 'duration': 0.37288, 'confidence': 0.426},
#   {'start': 66.83774, 'duration': 0.36885, 'confidence': 0.354},
#   {'start': 67.20659, 'duration': 0.37042, 'confidence': 0.315},
#   {'start': 67.57701, 'duration': 0.37591, 'confidence': 0.312},
#   {'start': 67.95292, 'duration': 0.37382, 'confidence': 0.384},
#   {'start': 68.32673, 'duration': 0.36847, 'confidence': 0.396},
#   {'start': 68.6952, 'duration': 0.36275, 'confidence': 0.31},
#   {'start': 69.05795, 'duration': 0.36662, 'confidence': 0.203},
#   {'start': 69.42456, 'duration': 0.36818, 'confidence': 0.084},
#   {'start': 69.79274, 'duration': 0.36642, 'confidence': 0.188},
#   {'start': 70.15916, 'duration': 0.3647, 'confidence': 0.33},
#   {'start': 70.52387, 'duration': 0.36364, 'confidence': 0.411},
#   {'start': 70.88751, 'duration': 0.3662, 'confidence': 0.526},
#   {'start': 71.2537, 'duration': 0.36846, 'confidence': 0.531},
#   {'start': 71.62216, 'duration': 0.36809, 'confidence': 0.355},
#   {'start': 71.99025, 'duration': 0.3664, 'confidence': 0.358},
#   {'start': 72.35665, 'duration': 0.36705, 'confidence': 0.244},
#   {'start': 72.72371, 'duration': 0.36508, 'confidence': 0.217},
#   {'start': 73.08878, 'duration': 0.36606, 'confidence': 0.374},
#   {'start': 73.45484, 'duration': 0.36606, 'confidence': 0.334},
#   {'start': 73.8209, 'duration': 0.36409, 'confidence': 0.317},
#   {'start': 74.18499, 'duration': 0.36474, 'confidence': 0.305},
#   {'start': 74.54973, 'duration': 0.36408, 'confidence': 0.361},
#   {'start': 74.91381, 'duration': 0.36178, 'confidence': 0.278},
#   {'start': 75.27559, 'duration': 0.36473, 'confidence': 0.354},
#   {'start': 75.64032, 'duration': 0.36407, 'confidence': 0.318},
#   {'start': 76.00439, 'duration': 0.36537, 'confidence': 0.237},
#   {'start': 76.36976, 'duration': 0.36471, 'confidence': 0.202},
#   {'start': 76.73447, 'duration': 0.3647, 'confidence': 0.218},
#   {'start': 77.09917, 'duration': 0.36468, 'confidence': 0.201},
#   {'start': 77.46385, 'duration': 0.36598, 'confidence': 0.275},
#   {'start': 77.82983, 'duration': 0.36628, 'confidence': 0.235},
#   {'start': 78.19612, 'duration': 0.36659, 'confidence': 0.268},
#   {'start': 78.56271, 'duration': 0.3646, 'confidence': 0.311},
#   {'start': 78.92731, 'duration': 0.36654, 'confidence': 0.237},
#   {'start': 79.29384, 'duration': 0.36488, 'confidence': 0.276},
#   {'start': 79.65872, 'duration': 0.36385, 'confidence': 0.334},
#   {'start': 80.02257, 'duration': 0.36611, 'confidence': 0.237},
#   {'start': 80.38868, 'duration': 0.36444, 'confidence': 0.336},
#   {'start': 80.75311, 'duration': 0.36471, 'confidence': 0.285},
#   {'start': 81.11782, 'duration': 0.36531, 'confidence': 0.525},
#   {'start': 81.48313, 'duration': 0.36754, 'confidence': 0.49},
#   {'start': 81.85067, 'duration': 0.3678, 'confidence': 0.459},
#   {'start': 82.21847, 'duration': 0.36776, 'confidence': 0.426},
#   {'start': 82.58623, 'duration': 0.36376, 'confidence': 0.313},
#   {'start': 82.94999, 'duration': 0.3696, 'confidence': 0.28},
#   {'start': 83.31959, 'duration': 0.36826, 'confidence': 0.205},
#   {'start': 83.68785, 'duration': 0.36919, 'confidence': 0.176},
#   {'start': 84.05704, 'duration': 0.3672, 'confidence': 0.126},
#   {'start': 84.42424, 'duration': 0.3675, 'confidence': 0.161},
#   {'start': 84.79173, 'duration': 0.36747, 'confidence': 0.395},
#   {'start': 85.1592, 'duration': 0.36942, 'confidence': 0.342},
#   {'start': 85.52863, 'duration': 0.36417, 'confidence': 0.357},
#   {'start': 85.89279, 'duration': 0.3658, 'confidence': 0.291},
#   {'start': 86.25859, 'duration': 0.36448, 'confidence': 0.327},
#   {'start': 86.62307, 'duration': 0.36351, 'confidence': 0.233},
#   {'start': 86.98658, 'duration': 0.36352, 'confidence': 0.302},
#   {'start': 87.35011, 'duration': 0.36419, 'confidence': 0.306},
#   {'start': 87.7143, 'duration': 0.36422, 'confidence': 0.231},
#   {'start': 88.07852, 'duration': 0.36491, 'confidence': 0.231},
#   {'start': 88.44343, 'duration': 0.36662, 'confidence': 0.239},
#   {'start': 88.81006, 'duration': 0.36637, 'confidence': 0.2},
#   {'start': 89.17642, 'duration': 0.36544, 'confidence': 0.212},
# ...
#   {'start': 139.12956, 'duration': 0.18314, 'confidence': 0.297},
#   {'start': 139.3127, 'duration': 0.18199, 'confidence': 0.391},
#   {'start': 139.49469, 'duration': 0.18199, 'confidence': 0.391},
#   {'start': 139.67668, 'duration': 0.18215, 'confidence': 0.382},
#   {'start': 139.85884, 'duration': 0.18215, 'confidence': 0.382},
#   {'start': 140.04099, 'duration': 0.18215, 'confidence': 0.356},
#   {'start': 140.22314, 'duration': 0.18215, 'confidence': 0.356},
#   {'start': 140.40529, 'duration': 0.18296, 'confidence': 0.317},
#   {'start': 140.58826, 'duration': 0.18296, 'confidence': 0.317},
#   {'start': 140.77121, 'duration': 0.18296, 'confidence': 0.392},
#   {'start': 140.95416, 'duration': 0.18296, 'confidence': 0.392},
#   {'start': 141.13713, 'duration': 0.18328, 'confidence': 0.52},
#   {'start': 141.3204, 'duration': 0.18328, 'confidence': 0.52},
#   {'start': 141.50368, 'duration': 0.18295, 'confidence': 0.505},
#   {'start': 141.68663, 'duration': 0.18295, 'confidence': 0.505},
#   {'start': 141.86958, 'duration': 0.1836, 'confidence': 0.437},
#   {'start': 142.05318, 'duration': 0.1836, 'confidence': 0.437},
#   {'start': 142.23677, 'duration': 0.18343, 'confidence': 0.544},
#   {'start': 142.4202, 'duration': 0.18343, 'confidence': 0.544},
#   {'start': 142.60362, 'duration': 0.18342, 'confidence': 0.608},
#   {'start': 142.78705, 'duration': 0.18342, 'confidence': 0.608},
#   {'start': 142.97047, 'duration': 0.18178, 'confidence': 0.415},
#   {'start': 143.15225, 'duration': 0.18178, 'confidence': 0.415},
#   {'start': 143.33403, 'duration': 0.18194, 'confidence': 0.403},
#   {'start': 143.51598, 'duration': 0.18194, 'confidence': 0.403},
#   {'start': 143.6979, 'duration': 0.18242, 'confidence': 0.291},
#   {'start': 143.88034, 'duration': 0.18242, 'confidence': 0.291},
#   {'start': 144.06276, 'duration': 0.18291, 'confidence': 0.247},
#   {'start': 144.24567, 'duration': 0.18291, 'confidence': 0.247},
#   {'start': 144.42857, 'duration': 0.18372, 'confidence': 0.365},
#   {'start': 144.61229, 'duration': 0.18372, 'confidence': 0.365},
#   {'start': 144.796, 'duration': 0.18436, 'confidence': 0.25},
#   {'start': 144.98038, 'duration': 0.18436, 'confidence': 0.25},
#   {'start': 145.16473, 'duration': 0.18338, 'confidence': 0.339},
#   {'start': 145.34811, 'duration': 0.18338, 'confidence': 0.339},
#   {'start': 145.5315, 'duration': 0.18305, 'confidence': 0.428},
#   {'start': 145.71454, 'duration': 0.18305, 'confidence': 0.428},
#   {'start': 145.89758, 'duration': 0.18304, 'confidence': 0.458},
#   {'start': 146.08063, 'duration': 0.18304, 'confidence': 0.458},
#   {'start': 146.26367, 'duration': 0.18304, 'confidence': 0.317},
#   {'start': 146.4467, 'duration': 0.18304, 'confidence': 0.317},
#   {'start': 146.62975, 'duration': 0.18238, 'confidence': 0.249},
#   {'start': 146.81212, 'duration': 0.18238, 'confidence': 0.249},
#   {'start': 146.9945, 'duration': 0.18336, 'confidence': 0.252},
#   {'start': 147.17787, 'duration': 0.18336, 'confidence': 0.252},
#   {'start': 147.36124, 'duration': 0.18255, 'confidence': 0.229},
#   {'start': 147.54378, 'duration': 0.18255, 'confidence': 0.229},
#   {'start': 147.72633, 'duration': 0.18304, 'confidence': 0.254},
#   {'start': 147.90936, 'duration': 0.18304, 'confidence': 0.254},
#   {'start': 148.0924, 'duration': 0.18271, 'confidence': 0.294},
#   {'start': 148.27512, 'duration': 0.18271, 'confidence': 0.294},
#   {'start': 148.45782, 'duration': 0.18222, 'confidence': 0.257},
#   {'start': 148.64005, 'duration': 0.18222, 'confidence': 0.257},
#   {'start': 148.82228, 'duration': 0.18223, 'confidence': 0.364},
#   {'start': 149.0045, 'duration': 0.18223, 'confidence': 0.364},
#   {'start': 149.18674, 'duration': 0.18386, 'confidence': 0.308},
#   {'start': 149.37059, 'duration': 0.18386, 'confidence': 0.308},
#   {'start': 149.55444, 'duration': 0.18272, 'confidence': 0.329},
#   {'start': 149.73717, 'duration': 0.18272, 'confidence': 0.329},
#   {'start': 149.91988, 'duration': 0.18256, 'confidence': 0.356},
#   {'start': 150.10245, 'duration': 0.18256, 'confidence': 0.356},
#   {'start': 150.285, 'duration': 0.18223, 'confidence': 0.411},
#   {'start': 150.46722, 'duration': 0.18223, 'confidence': 0.411},
#   {'start': 150.64946, 'duration': 0.18305, 'confidence': 0.259},
#   {'start': 150.8325, 'duration': 0.18305, 'confidence': 0.259},
#   {'start': 151.01555, 'duration': 0.18371, 'confidence': 0.34},
#   {'start': 151.19926, 'duration': 0.18371, 'confidence': 0.34},
#   {'start': 151.38297, 'duration': 0.1824, 'confidence': 0.35},
#   {'start': 151.56535, 'duration': 0.1824, 'confidence': 0.35},
#   {'start': 151.74777, 'duration': 0.18176, 'confidence': 0.45},
#   {'start': 151.92952, 'duration': 0.18176, 'confidence': 0.45},
#   {'start': 152.11128, 'duration': 0.18112, 'confidence': 0.373},
#   {'start': 152.2924, 'duration': 0.18112, 'confidence': 0.373},
#   {'start': 152.47351, 'duration': 0.18194, 'confidence': 0.448},
#   {'start': 152.65546, 'duration': 0.18194, 'confidence': 0.448},
#   {'start': 152.83739, 'duration': 0.18277, 'confidence': 0.397},
#   {'start': 153.02017, 'duration': 0.18277, 'confidence': 0.397},
#   {'start': 153.20294, 'duration': 0.18295, 'confidence': 0.444},
#   {'start': 153.3859, 'duration': 0.18295, 'confidence': 0.444},
#   {'start': 153.56885, 'duration': 0.18231, 'confidence': 0.269},
#   {'start': 153.75117, 'duration': 0.18231, 'confidence': 0.269},
#   {'start': 153.93349, 'duration': 0.18397, 'confidence': 0.353},
#   {'start': 154.11745, 'duration': 0.18397, 'confidence': 0.353},
#   {'start': 154.30142, 'duration': 0.18301, 'confidence': 0.279},
#   {'start': 154.48444, 'duration': 0.18301, 'confidence': 0.279},
#   {'start': 154.66743, 'duration': 0.18367, 'confidence': 0.38},
#   {'start': 154.8511, 'duration': 0.18367, 'confidence': 0.38},
#   {'start': 155.03477, 'duration': 0.1837, 'confidence': 0.355},
#   {'start': 155.21848, 'duration': 0.1837, 'confidence': 0.355},
#   {'start': 155.40218, 'duration': 0.18273, 'confidence': 0.423},
#   {'start': 155.5849, 'duration': 0.18273, 'confidence': 0.423},
#   {'start': 155.76762, 'duration': 0.18373, 'confidence': 0.406},
#   {'start': 155.95135, 'duration': 0.18373, 'confidence': 0.406},
#   {'start': 156.13509, 'duration': 0.18424, 'confidence': 0.434},
#   {'start': 156.31932, 'duration': 0.18424, 'confidence': 0.434},
#   {'start': 156.50356, 'duration': 0.18343, 'confidence': 0.278},
#   {'start': 156.687, 'duration': 0.18343, 'confidence': 0.278},
#   {'start': 156.87044, 'duration': 0.18279, 'confidence': 0.258},
#   {'start': 157.05322, 'duration': 0.18279, 'confidence': 0.258},
#   {'start': 157.23602, 'duration': 0.18183, 'confidence': 0.201},
#   {'start': 157.41785, 'duration': 0.18183, 'confidence': 0.201},
#   {'start': 157.59967, 'duration': 0.18167, 'confidence': 0.199},
#   {'start': 157.78134, 'duration': 0.18167, 'confidence': 0.199},
#   {'start': 157.96301, 'duration': 0.1825, 'confidence': 0.161},
#   {'start': 158.14551, 'duration': 0.1825, 'confidence': 0.161},
#   {'start': 158.328, 'duration': 0.18185, 'confidence': 0.15},
#   {'start': 158.50986, 'duration': 0.18185, 'confidence': 0.15},
#   {'start': 158.69171, 'duration': 0.18202, 'confidence': 0.206},
#   {'start': 158.87373, 'duration': 0.18202, 'confidence': 0.206},
#   {'start': 159.05576, 'duration': 0.18251, 'confidence': 0.258},
#   {'start': 159.23827, 'duration': 0.18251, 'confidence': 0.258},
#   {'start': 159.42078, 'duration': 0.18431, 'confidence': 0.305},
#   {'start': 159.60509, 'duration': 0.18431, 'confidence': 0.305},
#   {'start': 159.7894, 'duration': 0.18448, 'confidence': 0.39},
#   {'start': 159.97388, 'duration': 0.18448, 'confidence': 0.39},
#   {'start': 160.15836, 'duration': 0.18399, 'confidence': 0.37},
#   {'start': 160.34236, 'duration': 0.18399, 'confidence': 0.37},
#   {'start': 160.52635, 'duration': 0.18416, 'confidence': 0.473},
#   {'start': 160.71051, 'duration': 0.18416, 'confidence': 0.473},
#   {'start': 160.89467, 'duration': 0.18465, 'confidence': 0.385},
#   {'start': 161.07932, 'duration': 0.18465, 'confidence': 0.385},
#   {'start': 161.26398, 'duration': 0.18384, 'confidence': 0.299},
#   {'start': 161.44781, 'duration': 0.18384, 'confidence': 0.299},
#   {'start': 161.63165, 'duration': 0.18351, 'confidence': 0.296},
#   {'start': 161.81516, 'duration': 0.18351, 'confidence': 0.296},
#   {'start': 161.99867, 'duration': 0.18187, 'confidence': 0.41},
#   {'start': 162.18054, 'duration': 0.18187, 'confidence': 0.41},
#   {'start': 162.36243, 'duration': 0.1827, 'confidence': 0.316},
#   {'start': 162.5451, 'duration': 0.1827, 'confidence': 0.316},
#   {'start': 162.72781, 'duration': 0.18302, 'confidence': 0.394},
#   {'start': 162.91083, 'duration': 0.18302, 'confidence': 0.394},
#   {'start': 163.09386, 'duration': 0.18237, 'confidence': 0.459},
#   {'start': 163.27623, 'duration': 0.18237, 'confidence': 0.459},
#   {'start': 163.4586, 'duration': 0.18237, 'confidence': 0.511},
#   {'start': 163.64098, 'duration': 0.18237, 'confidence': 0.511},
#   {'start': 163.82333, 'duration': 0.18287, 'confidence': 0.425},
#   {'start': 164.00621, 'duration': 0.18287, 'confidence': 0.425},
#   {'start': 164.18909, 'duration': 0.18238, 'confidence': 0.434},
#   {'start': 164.37144, 'duration': 0.18238, 'confidence': 0.434},
#   {'start': 164.55383, 'duration': 0.18369, 'confidence': 0.378},
#   {'start': 164.73752, 'duration': 0.18369, 'confidence': 0.378},
#   {'start': 164.9212, 'duration': 0.18303, 'confidence': 0.423},
#   {'start': 165.10423, 'duration': 0.18303, 'confidence': 0.423},
#   {'start': 165.28726, 'duration': 0.18172, 'confidence': 0.3},
#   {'start': 165.46898, 'duration': 0.18172, 'confidence': 0.3},
#   {'start': 165.6507, 'duration': 0.18221, 'confidence': 0.284},
#   {'start': 165.8329, 'duration': 0.18221, 'confidence': 0.284},
#   {'start': 166.0151, 'duration': 0.18171, 'confidence': 0.219},
#   {'start': 166.19682, 'duration': 0.18171, 'confidence': 0.219},
#   {'start': 166.37854, 'duration': 0.18302, 'confidence': 0.236},
#   {'start': 166.56155, 'duration': 0.18302, 'confidence': 0.236},
#   {'start': 166.74458, 'duration': 0.18433, 'confidence': 0.16},
#   {'start': 166.92892, 'duration': 0.18433, 'confidence': 0.16},
#   {'start': 167.11325, 'duration': 0.18237, 'confidence': 0.169},
#   {'start': 167.29562, 'duration': 0.18237, 'confidence': 0.169},
#   {'start': 167.478, 'duration': 0.18302, 'confidence': 0.169},
#   {'start': 167.66101, 'duration': 0.18302, 'confidence': 0.169},
#   {'start': 167.84404, 'duration': 0.18417, 'confidence': 0.17},
#   {'start': 168.02821, 'duration': 0.18417, 'confidence': 0.17},
#   {'start': 168.21239, 'duration': 0.184, 'confidence': 0.138},
#   {'start': 168.39638, 'duration': 0.184, 'confidence': 0.138},
#   {'start': 168.58038, 'duration': 0.18319, 'confidence': 0.185},
#   {'start': 168.76357, 'duration': 0.18319, 'confidence': 0.185},
#   {'start': 168.94676, 'duration': 0.18204, 'confidence': 0.24},
#   {'start': 169.1288, 'duration': 0.18204, 'confidence': 0.24},
#   {'start': 169.31084, 'duration': 0.18057, 'confidence': 0.215},
#   {'start': 169.49141, 'duration': 0.18057, 'confidence': 0.215},
#   {'start': 169.67198, 'duration': 0.182, 'confidence': 0.261},
#   {'start': 169.85397, 'duration': 0.182, 'confidence': 0.261},
#   {'start': 170.03596, 'duration': 0.18231, 'confidence': 0.261},
#   {'start': 170.21828, 'duration': 0.18231, 'confidence': 0.261},
#   {'start': 170.40057, 'duration': 0.18262, 'confidence': 0.261},
#   {'start': 170.5832, 'duration': 0.18262, 'confidence': 0.261},
#   {'start': 170.76581, 'duration': 0.18292, 'confidence': 0.261},
#   {'start': 170.94875, 'duration': 0.18292, 'confidence': 0.261},
#   {'start': 171.13165, 'duration': 0.18323, 'confidence': 0.261},
#   {'start': 171.3149, 'duration': 0.18323, 'confidence': 0.261},
#   {'start': 171.49812, 'duration': 0.18211, 'confidence': 0.261},
#   {'start': 171.68024, 'duration': 0.18211, 'confidence': 0.261},
#   {'start': 171.86237, 'duration': 0.18269, 'confidence': 0.343},
#   {'start': 172.04504, 'duration': 0.18269, 'confidence': 0.343},
#   {'start': 172.22774, 'duration': 0.18343, 'confidence': 0.338},
#   {'start': 172.41116, 'duration': 0.18343, 'confidence': 0.338},
#   {'start': 172.5946, 'duration': 0.18408, 'confidence': 0.253},
#   {'start': 172.77869, 'duration': 0.18408, 'confidence': 0.253},
#   {'start': 172.96277, 'duration': 0.18474, 'confidence': 0.226},
#   {'start': 173.1475, 'duration': 0.18474, 'confidence': 0.226},
#   {'start': 173.33224, 'duration': 0.18392, 'confidence': 0.139},
#   {'start': 173.51616, 'duration': 0.18392, 'confidence': 0.139},
#   {'start': 173.70007, 'duration': 0.18359, 'confidence': 0.282},
#   {'start': 173.88367, 'duration': 0.18359, 'confidence': 0.282},
#   {'start': 174.06725, 'duration': 0.18358, 'confidence': 0.202},
#   {'start': 174.25082, 'duration': 0.18358, 'confidence': 0.202},
#   {'start': 174.4344, 'duration': 0.18407, 'confidence': 0.276},
#   {'start': 174.61848, 'duration': 0.18407, 'confidence': 0.276},
#   {'start': 174.80255, 'duration': 0.18521, 'confidence': 0.196},
#   {'start': 174.98776, 'duration': 0.18521, 'confidence': 0.196},
#   {'start': 175.17297, 'duration': 0.18447, 'confidence': 0.225},
#   {'start': 175.35745, 'duration': 0.18447, 'confidence': 0.225},
#   {'start': 175.54192, 'duration': 0.18431, 'confidence': 0.143},
#   {'start': 175.72623, 'duration': 0.18431, 'confidence': 0.143},
#   {'start': 175.91054, 'duration': 0.18431, 'confidence': 0.208},
#   {'start': 176.09485, 'duration': 0.18431, 'confidence': 0.208},
#   {'start': 176.27914, 'duration': 0.1834, 'confidence': 0.203},
#   {'start': 176.46255, 'duration': 0.1834, 'confidence': 0.203},
#   {'start': 176.64597, 'duration': 0.18356, 'confidence': 0.148},
#   {'start': 176.82951, 'duration': 0.18356, 'confidence': 0.148},
#   {'start': 177.01309, 'duration': 0.18241, 'confidence': 0.119},
#   {'start': 177.1955, 'duration': 0.18241, 'confidence': 0.119},
#   {'start': 177.37791, 'duration': 0.18028, 'confidence': 0.144},
#   {'start': 177.5582, 'duration': 0.18028, 'confidence': 0.144},
#   {'start': 177.73848, 'duration': 0.18052, 'confidence': 0.099},
#   {'start': 177.919, 'duration': 0.18052, 'confidence': 0.099},
#   {'start': 178.09952, 'duration': 0.18125, 'confidence': 0.249},
#   {'start': 178.28078, 'duration': 0.18125, 'confidence': 0.249},
#   {'start': 178.46204, 'duration': 0.18264, 'confidence': 0.187},
#   {'start': 178.64467, 'duration': 0.18264, 'confidence': 0.187},
#   {'start': 178.8273, 'duration': 0.1841, 'confidence': 0.173},
#   {'start': 179.01141, 'duration': 0.1841, 'confidence': 0.173},
#   {'start': 179.19551, 'duration': 0.18442, 'confidence': 0.121},
#   {'start': 179.37993, 'duration': 0.18442, 'confidence': 0.121},
#   {'start': 179.56435, 'duration': 0.18441, 'confidence': 0.128},
#   {'start': 179.74876, 'duration': 0.18441, 'confidence': 0.128},
#   {'start': 179.93318, 'duration': 0.18506, 'confidence': 0.18},
#   {'start': 180.11823, 'duration': 0.18506, 'confidence': 0.18},
#   {'start': 180.30328, 'duration': 0.18489, 'confidence': 0.144},
#   {'start': 180.48817, 'duration': 0.18489, 'confidence': 0.144},
#   {'start': 180.67307, 'duration': 0.18422, 'confidence': 0.12},
#   {'start': 180.85728, 'duration': 0.18422, 'confidence': 0.12},
#   {'start': 181.0415, 'duration': 0.18356, 'confidence': 0.19},
#   {'start': 181.22508, 'duration': 0.18356, 'confidence': 0.19},
#   {'start': 181.40865, 'duration': 0.18225, 'confidence': 0.197},
#   {'start': 181.59088, 'duration': 0.18225, 'confidence': 0.197},
#   {'start': 181.77313, 'duration': 0.18183, 'confidence': 0.169},
#   {'start': 181.95496, 'duration': 0.18183, 'confidence': 0.169},
#   {'start': 182.1368, 'duration': 0.18224, 'confidence': 0.2},
#   {'start': 182.31903, 'duration': 0.18224, 'confidence': 0.2},
#   {'start': 182.50127, 'duration': 0.18207, 'confidence': 0.205},
#   {'start': 182.68333, 'duration': 0.18207, 'confidence': 0.205},
#   {'start': 182.8654, 'duration': 0.18215, 'confidence': 0.17},
#   {'start': 183.04755, 'duration': 0.18215, 'confidence': 0.17},
#   {'start': 183.22969, 'duration': 0.18214, 'confidence': 0.132},
#   {'start': 183.41183, 'duration': 0.18214, 'confidence': 0.132},
#   ...]}

# %%
for d in sdf:
    print(d)
# Out:
# isrc
# title
# artist
# lyrics
# lyrics_lines
# lyrics_string
# nrc_score
# str_vader_score
# line_vader_score
# spot_audio_analysis
# spot_audio_features
# line_albert_score

# %%
# loading kaggle data files

# file with basic song information, such as song name, artist name
df_song_info = pd.read_csv('billboard_hot_100_kaggle/song_info.csv')

# sample 10 songs from dataset
df_song_sample = df_song_info.sample(n=10, random_state=42)

# find lyrics
df_song_sample['lyrics'] = df_song_sample.apply(find_lyrics, axis=1)

# remove songs if lyrics information is None (returned none from genius)
df_lyrics_sample = df_song_sample.dropna()
df_ly = df_lyrics_sample['lyrics']
# Out:
# Searching for "Contrabando Y Traicion" by Ramon Ayala Y Sus Bravos Del Norte...
# No results found for: 'Contrabando Y Traicion Ramon Ayala Y Sus Bravos Del Norte'
# Searching for "Nordlicht" by Flug 8...
# No results found for: 'Nordlicht Flug 8'
# Searching for "I've Got A Woman" by Ray Charles...
# Done.
# Searching for "Crazy in Love" by Daniela Andrade...
# Done.
# Searching for "Don't Get Too High" by Bryson Tiller...
# Done.
# Searching for "Wannabe" by Spice Girls...
# Done.
# Searching for "Best Life" by Hardy Caprio...
# Done.
# Searching for "Clandestino" by Shakira...
# Done.
# Searching for "Woman Like Me (feat. Nicki Minaj)" by Little Mix...
# Done.
# Searching for "Take Me To Church (Acoustic Cover) feat. Matt Wright" by Megan Davies...
# No results found for: 'Take Me To Church (Acoustic Cover) feat. Matt Wright Megan Davies'

# %%
line_albert_surprise
# Out:
# [1.4744282916362863,
#  0.9202406413096469,
#  1.6364919737097807,
#  1.5113379742833786,
#  0.2501261677243747]
